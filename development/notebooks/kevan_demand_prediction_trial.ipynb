# %%
import pandas as pd
import numpy as np

# %%
df_original = df_ml_movies = pd.read_excel('../datasets/anonymised_orders_original.xlsx')
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22976 entries, 0 to 22975
# Data columns (total 81 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         22976 non-null  object
#  1   Email                        14869 non-null  object
#  2   Financial Status             10942 non-null  object
#  3   Paid at                      10831 non-null  object
#  4   Fulfillment Status           10942 non-null  object
#  5   Fulfilled at                 10801 non-null  object
#  6   Accepts Marketing            10942 non-null  object
#  7   Currency                     10942 non-null  object
#  8   Subtotal                     10942 non-null  float64
#  9   Shipping                     10942 non-null  float64
#  10  Taxes                        10942 non-null  float64
#  11  Total                        10942 non-null  float64
# ...

# %%
pd.set_option('display.max_columns', None)
df_original.head(10)
# Out:
#     Name                  Email Financial Status                    Paid at  \
# 0  #3200  893696139@yopmail.com             paid  2022-04-29 18:29:50 +0800
# 1  #3200  893696139@yopmail.com              NaN                        NaN
# 2  #3070  893696139@yopmail.com             paid  2022-04-22 18:09:00 +0800
# 3  #3070  893696139@yopmail.com              NaN                        NaN
# 4  #3815                    NaN             paid  2022-05-29 19:37:46 +0800
# 5  11752  681271354@yopmail.com             paid  2023-07-20 17:00:28 +0800
# 6  11752  681271354@yopmail.com              NaN                        NaN
# 7  11752  681271354@yopmail.com              NaN                        NaN
# 8  10941  995325256@yopmail.com             paid  2023-06-03 16:06:32 +0800
# 9  35993  883769088@yopmail.com             paid  2022-01-22 05:52:46 +0800
#
#   Fulfillment Status               Fulfilled at Accepts Marketing Currency  \
# ...

# %%
df_original[df_original['Total'].isnull()]
# here we see sometimes the total order balance data isn't there but the customer did buy something (see columns about LineItem)
# Out:
#         Name                  Email Financial Status Paid at  \
# 1      #3200  893696139@yopmail.com              NaN     NaN
# 3      #3070  893696139@yopmail.com              NaN     NaN
# 6      11752  681271354@yopmail.com              NaN     NaN
# 7      11752  681271354@yopmail.com              NaN     NaN
# 12     #3819  471528779@yopmail.com              NaN     NaN
# ...      ...                    ...              ...     ...
# 22971  #2303                    NaN              NaN     NaN
# 22972  #2303                    NaN              NaN     NaN
# 22973  #2303                    NaN              NaN     NaN
# 22974  #2303                    NaN              NaN     NaN
# 22975  #2303                    NaN              NaN     NaN
#
#       Fulfillment Status Fulfilled at Accepts Marketing Currency  Subtotal  \
# 1                    NaN          NaN               NaN      NaN       NaN
# 3                    NaN          NaN               NaN      NaN       NaN
# ...

# %%
df_original[df_original['Lineitem name'].isnull()]
# we can use Linetem name to be the
# Out:
# Empty DataFrame
# ...

# %%
df_original['Name'].value_counts()
# Out:
# 36047    31
# #4504    26
# #9234    25
# #6876    21
# #3489    20
#          ..
# #3840     1
# #5433     1
# #3774     1
# #7505     1
# #8630     1
# Name: Name, Length: 10937, dtype: int64

# %%
df_original[df_original['Name'] == 36047]
# Out:
#        Name                  Email Financial Status  \
# 8114  36047  635422575@yopmail.com             paid
# 8115  36047  635422575@yopmail.com              NaN
# 8116  36047  635422575@yopmail.com              NaN
# 8117  36047  635422575@yopmail.com              NaN
# 8118  36047  635422575@yopmail.com              NaN
# 8119  36047  635422575@yopmail.com              NaN
# 8120  36047  635422575@yopmail.com              NaN
# 8121  36047  635422575@yopmail.com              NaN
# 8122  36047  635422575@yopmail.com              NaN
# 8123  36047  635422575@yopmail.com              NaN
# 8124  36047  635422575@yopmail.com              NaN
# 8125  36047  635422575@yopmail.com              NaN
# 8126  36047  635422575@yopmail.com              NaN
# 8127  36047  635422575@yopmail.com              NaN
# 8128  36047  635422575@yopmail.com              NaN
# 8129  36047  635422575@yopmail.com              NaN
# 8130  36047  635422575@yopmail.com              NaN
# ...

# %%
df_null_dropped = df_original.dropna(axis=1)
df_null_dropped
# Out:
#         Name                 Created at  Lineitem quantity  \
# 0      #3200  2022-04-29 18:29:49 +0800                  1
# 1      #3200  2022-04-29 18:29:49 +0800                  1
# 2      #3070  2022-04-22 18:08:59 +0800                  1
# 3      #3070  2022-04-22 18:08:59 +0800                  2
# 4      #3815  2022-05-29 19:37:45 +0800                  1
# ...      ...                        ...                ...
# 22971  #2303  2022-02-23 20:23:34 +0800                  1
# 22972  #2303  2022-02-23 20:23:34 +0800                  1
# 22973  #2303  2022-02-23 20:23:34 +0800                  1
# 22974  #2303  2022-02-23 20:23:34 +0800                  1
# 22975  #2303  2022-02-23 20:23:34 +0800                  1
#
#                                            Lineitem name  Lineitem price  \
# 0                                         Arzuaga blanco            49.0
# 1                                        Arzuaga reserva            94.0
# ...

# %%
print('Lineitem requires shipping')
print(df_null_dropped['Lineitem requires shipping'].value_counts())
print('--------------------------------------')

print('Lineitem taxable')
print(df_null_dropped['Lineitem taxable'].value_counts())
print('--------------------------------------')

print('Lineitem fulfillment status')
print(df_null_dropped['Lineitem fulfillment status'].value_counts())
print('--------------------------------------')

print('Lineitem discount')
print(df_null_dropped['Lineitem discount'].value_counts())
print('--------------------------------------')
# Out:
# Lineitem requires shipping
# True     20737
# False     2239
# Name: Lineitem requires shipping, dtype: int64
# --------------------------------------
# Lineitem taxable
# True     22383
# False      593
# Name: Lineitem taxable, dtype: int64
# --------------------------------------
# Lineitem fulfillment status
# fulfilled    22700
# pending        274
# partial          2
# Name: Lineitem fulfillment status, dtype: int64
# --------------------------------------
# Lineitem discount
# 0.0     21999
# 4.0        39
# 6.0        33
# 8.0        31
# 5.0        29
#         ...
# 8.9         1
# 22.2        1
# 82.4        1
# 34.0        1
# 1.8         1
# Name: Lineitem discount, Length: 283, dtype: int64
# --------------------------------------
